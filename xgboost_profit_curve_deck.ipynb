# %% [markdown]
# ## Dependencies

# %%
# !pip install xgboost --upgrade
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Collecting xgboost
#   Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl (173.5 MB)
#      |████████████████████████████████| 173.5 MB 51 kB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# Successfully installed xgboost-1.5.0

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.40.0.tar.gz (371 kB)
#      |████████████████████████████████| 371 kB 33.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.62.3)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.51.2)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.6)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.0.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (PEP 517) ... done
#   Created wheel for shap: filename=shap-0.40.0-cp37-cp37m-linux_x86_64.whl size=509243 sha256=08052c3bbd27cce6147ec0f5b27a029fe8c0d430ddce9b1034cd1c4e5d4f03d5
#   Stored in directory: /root/.cache/pip/wheels/ec/35/84/e304841ac4b910bc95fe9a6e5302eb2507b4333728851dcbfb
# Successfully built shap
# Installing collected packages: slicer, shap
# Successfully installed shap-0.40.0 slicer-0.0.7

# %%
import  pandas as pd,\
  google.colab as gcl,\
  xgboost as xgb,\
  sklearn.model_selection as slms,\
  shap as shp,\
  sklearn.metrics as slm,\
  numpy as np,\
  matplotlib.pyplot as pypl

# %%
pypl.style.use('bmh')

# %%
gcl.drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load Data

# %%
df_train_input = pd.read_csv(
  './drive/MyDrive/2021/NUS_MSBA/DBA5106/5106: FBA Project/Housing Price Dataset/train.csv',
  header='infer',
  index_col=False
)

# %%
df_cost_matrix = df_train_input[['SalePrice','WoodDeckSF']]

# %%
df_train_input.drop(columns=['OverallCond','OverallQual','SalePrice'
], inplace=True )

# %%
df_train_input['YrSold'] = df_train_input['YrSold'].astype('object')
df_train_input['MoSold'] = df_train_input['MoSold'].astype('object')
df_train_input['YearBuilt'] = df_train_input['YearBuilt'].astype('object')
df_train_input['YearRemodAdd'] = df_train_input['YearRemodAdd'].astype('object')
df_train_input['GarageYrBlt'] = df_train_input['GarageYrBlt'].astype('object')

# %%
df_train_input.dropna(subset=[ 'LotFrontage'] ,inplace=True)

# %%
categorical_columns = df_train_input.select_dtypes(include='object').columns.tolist()

df_train_dummies = pd.get_dummies(data=df_train_input,columns=categorical_columns)

# %%
(df_train_dummies['WoodDeckSF'] > 0).value_counts()
# Out:
# False    891
# True     801
# Name: WoodDeckSF, dtype: int64

# %%
print(891/(801+891))
# Out:
# 0.526595744680851

# %% [markdown]
# ## Classification

# %%
# Create classifier
df_train_dummies['class_wooddeck'] = df_train_dummies['WoodDeckSF'] > 0

# %%
input_features =  df_train_dummies.columns.tolist()
input_features.remove('Id')
input_features.remove('class_wooddeck')
input_features.remove('WoodDeckSF')

# %%
X_train, X_test, y_train, y_test = slms.train_test_split(
  df_train_dummies[input_features],
  df_train_dummies['class_wooddeck'],
  test_size=0.25 
)

# %%
xgboost_classifier = xgb.XGBClassifier(n_jobs=4,verbosity=3)

# %%
xgboost_classifier.fit(
  X_train, 
  y_train, 
#  early_stopping_rounds=10, 
  eval_metric="auc",
  eval_set=[(X_test, y_test)]
)
# Out:
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [11:32:55] DEBUG: ../src/gbm/gbtree.cc:155: Using tree method: 2
# [11:32:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 92 extra nodes, 0 pruned nodes, max_depth=6
# [0]	validation_0-auc:0.69411
# [11:32:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=6
# [1]	validation_0-auc:0.71131
# [11:32:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [2]	validation_0-auc:0.72015
# [11:32:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=6
# [3]	validation_0-auc:0.71965
# [11:32:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=6
# [4]	validation_0-auc:0.73379
# [11:32:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [5]	validation_0-auc:0.73849
# [11:32:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [6]	validation_0-auc:0.74274
# [11:32:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [7]	validation_0-auc:0.74719
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [8]	validation_0-auc:0.74730
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [9]	validation_0-auc:0.74983
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [10]	validation_0-auc:0.74952
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [11]	validation_0-auc:0.75002
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [12]	validation_0-auc:0.75192
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [13]	validation_0-auc:0.75243
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [14]	validation_0-auc:0.74354
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [15]	validation_0-auc:0.74419
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [16]	validation_0-auc:0.74623
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [17]	validation_0-auc:0.74656
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [18]	validation_0-auc:0.75209
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [19]	validation_0-auc:0.75575
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=6
# [20]	validation_0-auc:0.75626
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [21]	validation_0-auc:0.75767
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [22]	validation_0-auc:0.75691
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [23]	validation_0-auc:0.75225
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [24]	validation_0-auc:0.75321
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [25]	validation_0-auc:0.75411
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [26]	validation_0-auc:0.75624
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=6
# [27]	validation_0-auc:0.75124
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [28]	validation_0-auc:0.75252
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [29]	validation_0-auc:0.75404
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [30]	validation_0-auc:0.75044
# [11:32:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=6
# [31]	validation_0-auc:0.75169
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [32]	validation_0-auc:0.75221
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [33]	validation_0-auc:0.75212
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [34]	validation_0-auc:0.75218
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 74 extra nodes, 0 pruned nodes, max_depth=6
# [35]	validation_0-auc:0.74714
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [36]	validation_0-auc:0.74526
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [37]	validation_0-auc:0.74450
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [38]	validation_0-auc:0.74636
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [39]	validation_0-auc:0.74623
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [40]	validation_0-auc:0.74634
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [41]	validation_0-auc:0.74658
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [42]	validation_0-auc:0.74383
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [43]	validation_0-auc:0.74502
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [44]	validation_0-auc:0.74620
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [45]	validation_0-auc:0.74737
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [46]	validation_0-auc:0.74647
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [47]	validation_0-auc:0.74598
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [48]	validation_0-auc:0.74616
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [49]	validation_0-auc:0.74638
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [50]	validation_0-auc:0.74676
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [51]	validation_0-auc:0.74520
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=6
# [52]	validation_0-auc:0.74376
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [53]	validation_0-auc:0.74611
# [11:32:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=6
# [54]	validation_0-auc:0.74730
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [55]	validation_0-auc:0.74504
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [56]	validation_0-auc:0.74649
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [57]	validation_0-auc:0.74620
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [58]	validation_0-auc:0.74739
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [59]	validation_0-auc:0.74759
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [60]	validation_0-auc:0.74629
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [61]	validation_0-auc:0.74309
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [62]	validation_0-auc:0.74130
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [63]	validation_0-auc:0.74410
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [64]	validation_0-auc:0.74349
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [65]	validation_0-auc:0.74376
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [66]	validation_0-auc:0.74275
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [67]	validation_0-auc:0.74222
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [68]	validation_0-auc:0.74199
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [69]	validation_0-auc:0.74383
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [70]	validation_0-auc:0.74199
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 76 extra nodes, 0 pruned nodes, max_depth=6
# [71]	validation_0-auc:0.74372
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [72]	validation_0-auc:0.74296
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [73]	validation_0-auc:0.74237
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [74]	validation_0-auc:0.74345
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [75]	validation_0-auc:0.74248
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [76]	validation_0-auc:0.74376
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [77]	validation_0-auc:0.74466
# [11:32:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [78]	validation_0-auc:0.74412
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [79]	validation_0-auc:0.74546
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [80]	validation_0-auc:0.74495
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [81]	validation_0-auc:0.74573
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [82]	validation_0-auc:0.74687
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [83]	validation_0-auc:0.74679
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=6
# [84]	validation_0-auc:0.74564
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [85]	validation_0-auc:0.74544
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [86]	validation_0-auc:0.74372
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [87]	validation_0-auc:0.74282
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [88]	validation_0-auc:0.74275
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=6
# [89]	validation_0-auc:0.74098
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [90]	validation_0-auc:0.74177
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=6
# [91]	validation_0-auc:0.74374
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=6
# [92]	validation_0-auc:0.74293
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [93]	validation_0-auc:0.74128
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=6
# [94]	validation_0-auc:0.73984
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [95]	validation_0-auc:0.73948
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=6
# [96]	validation_0-auc:0.73921
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [97]	validation_0-auc:0.74004
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [98]	validation_0-auc:0.74029
# [11:32:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [99]	validation_0-auc:0.73919
# [11:32:59] ======== Monitor (0): Learner ========
# [11:32:59] Configure: 0s, 1 calls @ 0us
#
# [11:32:59] EvalOneIter: 0.096029s, 100 calls @ 96029us
#
# [11:32:59] GetGradient: 0.009305s, 100 calls @ 9305us
#
# [11:32:59] PredictRaw: 0.177763s, 100 calls @ 177763us
#
# [11:32:59] UpdateOneIter: 2.76849s, 100 calls @ 2768488us
#
# [11:32:59] ======== Monitor (0): GBTree ========
# [11:32:59] BoostNewTrees: 2.62808s, 100 calls @ 2628080us
#
# [11:32:59] CommitModel: 0.000107s, 100 calls @ 107us
#
# [11:32:59] ======== Monitor (0): TreePruner ========
# [11:32:59] PrunerUpdate: 0.064427s, 100 calls @ 64427us
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=3)

# %% [markdown]
# ## Profit curve

# %%
y_proba = xgboost_classifier.predict_proba(X_test)[:,1]

# %%
df_cost_matrix[df_cost_matrix['WoodDeckSF']>0 ]['SalePrice'].mean() - df_cost_matrix[df_cost_matrix['WoodDeckSF'] == 0 ]['SalePrice'].mean()
# Out:
# 47320.502286916366

# %%
df_cost_matrix[df_cost_matrix['WoodDeckSF']>0 ]['WoodDeckSF'].mean()
# Out:
# 195.71095334685597

# %%
# Cell values corresponds to those in the confusion matrix [[tp, fp], [fn, tn]]
costbenefit_mat = np.array(
  [
    [  df_cost_matrix[df_cost_matrix['WoodDeckSF']>0 ]['SalePrice'].mean() - df_cost_matrix[df_cost_matrix['WoodDeckSF'] == 0 ]['SalePrice'].mean()  
    , -60 *   df_cost_matrix[df_cost_matrix['WoodDeckSF']>0 ]['WoodDeckSF'].mean()  ], 
    [0,0]
  ]
)

# %%
thresholds = sorted(y_proba, reverse=True)

profits = []

# For each threshold, calculate profit
for T in thresholds:
    y_pred_profit = (y_proba > T).astype(int) # predict label based on the cutoff thresholds
    [[tn, fp], [fn, tp]] = slm.confusion_matrix(y_test.astype('int'), y_pred_profit) # get the confusion matrix for each threshold
    confusion_mat = np.array([[tp, fp], [fn, tn]])
    # Calculate total profit (in the test data) for this threshold
    profit = sum(sum(confusion_mat * costbenefit_mat))
    profits.append(profit)

# %%
# Profit curve plot
pypl.plot(np.linspace(0, 1, len(y_test)), profits)
pypl.xlabel('Test instances proportion (descending by score)')
pypl.ylabel('USD Profit')
pypl.title('Profit Curve - Wood Deck')

pypl.gcf().set_size_inches(14, 10)

pypl.savefig('./expected_value_wood_deck.png')

#pypl.show()
pypl.close('all')

# %%
print("The optimal total profit of ", max(profits),"is obtained with threshold of ", thresholds[np.argmax(profits)])
# Out:
# The optimal total profit of  7092433.57630305 is obtained with threshold of  0.013430812

# %% [markdown]
# ## Explainability

# %%
explainer = shp.TreeExplainer(xgboost_classifier)

shap_values = explainer.shap_values(X_test)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shp.summary_plot(shap_values,X_test)
